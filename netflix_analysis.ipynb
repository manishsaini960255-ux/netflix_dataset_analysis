# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"D:\VS CODE\netflix_data_analysis\data\netflix_titles.csv")
# data = df.head()
# print(data)
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   str
#  1   type          8807 non-null   str
#  2   title         8807 non-null   str
#  3   director      6173 non-null   str
#  4   cast          7982 non-null   str
#  5   country       7976 non-null   str
#  6   date_added    8797 non-null   str
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   str
#  9   duration      8804 non-null   str
#  10  listed_in     8807 non-null   str
#  11  description   8807 non-null   str
# dtypes: int64(1), str(11)
# memory usage: 825.8 KB

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df['director'] = df['director'].fillna('Unknown')
df['cast'] = df['cast'].fillna('Unknown')
df['country'] = df['country'].fillna('Unknown')
df['date_added'] = df['date_added'].fillna('Unknown')
df['rating'] = df['rating'].fillna('Unknown')
df['duration'] = df['duration'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df.duplicated()
# for remove duplication use --drop_duplication
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          Unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df['country'].value_counts().head(10)
# Out:
# country
# United States     2818
# India              972
# Unknown            831
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Name: count, dtype: int64

# %%
df['director'].value_counts().head(10)
# Out:
# director
# Unknown                   2634
# Rajiv Chilaka               19
# Raúl Campos, Jan Suter      18
# Suhas Kadav                 16
# Marcus Raboy                16
# Jay Karas                   14
# Cathy Garcia-Molina         13
# Youssef Chahine             12
# Martin Scorsese             12
# Jay Chapman                 12
# Name: count, dtype: int64

# %%
df['rating'].value_counts().head(10).sort_values()
# Out:
# rating
# NR         80
# TV-G      220
# PG        287
# TV-Y      307
# TV-Y7     334
# PG-13     490
# R         799
# TV-PG     863
# TV-14    2160
# TV-MA    3207
# Name: count, dtype: int64

# %%
df['release_year'].value_counts().sort_values()
# Out:
# release_year
# 1966       1
# 1961       1
# 1925       1
# 1947       1
# 1959       1
#         ...
# 2016     902
# 2020     953
# 2019    1030
# 2017    1032
# 2018    1147
# Name: count, Length: 74, dtype: int64

# %%
df['date_added'].value_counts().head(10).sort_values()
# Out:
# date_added
# July 1, 2019          52
# September 1, 2021     56
# October 1, 2019       60
# November 1, 2018      60
# July 1, 2021          60
# October 1, 2018       71
# December 31, 2019     74
# March 1, 2018         75
# November 1, 2019      89
# January 1, 2020      109
# Name: count, dtype: int64

# %%
df['type'].value_counts().sort_values().head()
# Out:
# type
# TV Show    2676
# Movie      6131
# Name: count, dtype: int64

# %%
print((df['type'].value_counts()/ len(df))*100)
# Out:
# type
# Movie      69.615079
# TV Show    30.384921
# Name: count, dtype: float64

# %%
df['listed_in'].str.split().explode().value_counts().head(20).sort_values()
# Out:
# listed_in
# Crime              470
# Documentaries,     486
# Shows              601
# Thrillers          634
# Family             641
# Children           641
# Independent        756
# Comedies           824
# Adventure,         848
# Dramas             909
# Romantic           986
# Action            1027
# Comedies,         1431
# Movies,           2266
# Dramas,           2281
# Shows,            2309
# &                 2611
# Movies            3421
# International     4103
# TV                5230
# Name: count, dtype: int64

# %%
df['listed_in'].value_counts().head(20).sort_values()
# Out:
# listed_in
# Comedies                                             110
# Crime TV Shows, International TV Shows, TV Dramas    110
# Comedies, Dramas, Independent Movies                 116
# International TV Shows, TV Dramas                    121
# Action & Adventure                                   128
# Action & Adventure, Dramas, International Movies     132
# Dramas, International Movies, Thrillers              134
# Dramas                                               138
# Comedies, International Movies, Romantic Movies      152
# Comedies, International Movies                       176
# Dramas, International Movies, Romantic Movies        180
# Documentaries, International Movies                  186
# Children & Family Movies, Comedies                   201
# Children & Family Movies                             215
# Kids' TV                                             220
# Dramas, Independent Movies, International Movies     252
# ...
